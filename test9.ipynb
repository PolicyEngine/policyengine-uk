# %%
from policyengine_uk.data import SPI_2020_21

SPI_2020_21().generate()

# %%
from policyengine_uk import Microsimulation

sim = Microsimulation(dataset=SPI_2020_21)

# %%
sim.calculate("income_tax").sum()/1e9
# Out:
# 194.97527893151815

# %%
import pandas as pd

df = pd.read_csv(SPI_2020_21.spi_data_file_path, delimiter="\t")

# %%
variables_to_add = [
    "income_tax",
    "adjusted_net_income",
    "other_tax_credits",
    "gift_aid",
    "received_allowances",
    "personal_allowance",
    "taxed_income",
    "taxed_dividend_income",
    "taxed_savings_income",
    "earned_taxable_income",
    "pension_contributions",
    "pension_contributions_relief",
    "earned_taxable_income",
    "taxable_pension_income",
    "private_pension_contributions_tax",
    "savings_allowance",
    "dividend_allowance",
    "property_allowance",
    "taxable_property_income",
    "property_income"
]

for variable in variables_to_add:
    df[f"zzz_policyengine_{variable}"] = sim.calculate(variable)

# %%
df["error"] = df.zzz_policyengine_income_tax - df.TOTTAX_DEVO_TXP
df["abs_error"] = df.error.abs()

# Add the EMPINC column
df['EMPINC'] = df.apply(lambda row: max(0, row['PAY'] + row['EPB'] - row['EXPS']) + 
                                    row['INCPBEN'] + row['OSSBEN'] + row['TAXTERM'] + 
                                    row['UBISJA'] + row['MOTHINC'], axis=1)

import numpy as np

# pandas show all rows
pd.set_option('display.max_rows', None)

# %%
(df[df.abs_error.between(100, np.inf)]
 .sort_values("abs_error", ascending=True)
 .head()
 .T
 .sort_index(key=lambda x: x.str.lower()))
# Out:
#                                                       118935     401891  \
# abs_error                                              100.0      100.0
# AGERANGE                                                   6          2
# BPADUE                                                     0          0
# CAPALL                                                     0          0
# COVNTS                                                     0          0
# DEFICIEN                                                   0          0
# DIVIDENDS                                                 15          0
# DSHIPS                                                     3          3
# EIDF                                                       0          0
# EMPINC                                                   200      31200
# EPB                                                        0          0
# error                                                 -100.0     -100.0
# EXPS                                                       0          0
# FACT                                                 70.6045  45.866177
# GIFTAID                                                    0          0
# GIFTINV                                                    0          0
# GORCODE                                                    3         11
# IIDF                                                       0          0
# INCBBS                                                  1490         80
# INCPBEN                                                    0          0
# INCPROP                                                    0          0
# INDUSTRY07                                              1600          M
# LLIR_RESTRICT_AMT_TOT                                      0          0
# LOSSBF                                                     0          0
# MAIND                                                      0          0
# MAINSRCE                                                   2          3
# MAR                                                     STBR       STIR
# MCAS                                                       0          0
# MOTHDED                                                    0          0
# MOTHINC                                                    0          0
# OSSBEN                                                     0          0
# OTHERINC                                                 200          0
# OTHERINV                                                   0          0
# PAS                                                    12500      12500
# PAY                                                      200      31200
# PENSION                                                16300          0
# PENSRLF                                                    0          0
# PROFITS                                                    0       5850
# PSAV_XS                                                    0          0
# SCOT_TXP                                                   0          1
# SEINC_NUM                                                  0          1
# SEISS                                                      0          0
# SEX                                                        1          1
# SPA                                                        1          0
# SREF                                                15182623   15466527
# SRP                                                     7850          0
# TAX_CRED                                                   0          0
# TAX_ST_AR_DEVO_TXP                                         0          0
# TAX_ST_AR_DEVO_WRIT                                        0          0
# TAX_ST_BR_DEVO_TXP                                      2410       2115
# TAX_ST_BR_DEVO_WRIT                                        0          0
# TAX_ST_HR_DEVO_TXP                                         0          0
# TAX_ST_HR_DEVO_WRIT                                        0          0
# TAX_ST_IR_DEVO_TXP                                         0       2495
# TAX_ST_SR_DEVO_TXP                                         0        395
# TAXINC                                                 13555      24630
# TAXPAYER                                                   1          1
# TAXTERM                                                    0          0
# TEI                                                    24550      37050
# TI                                                     26055      37130
# TII                                                     1505         80
# TOTTAX_DEVO_TXP                                         2510       5010
# UBISJA                                                     0          0
# WELSH_TXP                                                  0          0
# zzz_policyengine_adjusted_net_income                 26055.0    37130.0
# zzz_policyengine_dividend_allowance                   2000.0     2000.0
# zzz_policyengine_earned_taxable_income               12050.0    24550.0
# zzz_policyengine_gift_aid                                0.0        0.0
# zzz_policyengine_income_tax                           2410.0     4910.0
# zzz_policyengine_other_tax_credits                       0.0        0.0
# zzz_policyengine_pension_contributions                   0.0        0.0
# zzz_policyengine_pension_contributions_relief            0.0        0.0
# zzz_policyengine_personal_allowance                  12500.0    12500.0
# zzz_policyengine_private_pension_contributions_tax       0.0        0.0
# zzz_policyengine_property_allowance                      0.0        0.0
# zzz_policyengine_property_income                         0.0        0.0
# zzz_policyengine_received_allowances                 12500.0    12500.0
# zzz_policyengine_savings_allowance                       0.0        0.0
# zzz_policyengine_taxable_pension_income              16300.0        0.0
# zzz_policyengine_taxable_property_income                 0.0        0.0
# zzz_policyengine_taxed_dividend_income                   0.0        0.0
# zzz_policyengine_taxed_income                        12050.0    24550.0
# zzz_policyengine_taxed_savings_income                    0.0        0.0
#
#                                                        401779     474202  \
# abs_error                                               100.0      100.0
# AGERANGE                                                    1          5
# BPADUE                                                      0          0
# CAPALL                                                  41000          0
# COVNTS                                                      0          0
# DEFICIEN                                                    0          0
# DIVIDENDS                                                   0          0
# DSHIPS                                                      3          3
# EIDF                                                       90         95
# EMPINC                                                  28090       2370
# EPB                                                         0          0
# error                                                   100.0     -100.0
# EXPS                                                        0          0
# FACT                                                25.833991  45.729452
# GIFTAID                                                     0          0
# GIFTINV                                                     0          0
# GORCODE                                                     2         11
# IIDF                                                        0          0
# INCBBS                                                      0          0
# INCPBEN                                                     0          0
# INCPROP                                                     0      21300
# INDUSTRY07                                                  K       1600
# LLIR_RESTRICT_AMT_TOT                                       0       7095
# LOSSBF                                                      0          0
# MAIND                                                       0          0
# MAINSRCE                                                    3          1
# MAR                                                      NSHR       STIR
# MCAS                                                        0          0
# MOTHDED                                                     0          0
# MOTHINC                                                 28000          0
# OSSBEN                                                      0          0
# OTHERINC                                                    0          0
# OTHERINV                                                18000          0
# PAS                                                     12500      12500
# PAY                                                        90       2370
# PENSION                                                     0      13800
# PENSRLF                                                    90         95
# PROFITS                                                 51000          0
# PSAV_XS                                                     0          0
# SCOT_TXP                                                    0          1
# SEINC_NUM                                                   1          0
# SEISS                                                       0          0
# SEX                                                         1          2
# SPA                                                         0          0
# SREF                                                 15466405   15548833
# SRP                                                         0          0
# TAX_CRED                                                    0       1420
# TAX_ST_AR_DEVO_TXP                                          0          0
# TAX_ST_AR_DEVO_WRIT                                         0          0
# TAX_ST_BR_DEVO_TXP                                       5100       1525
# TAX_ST_BR_DEVO_WRIT                                         0          0
# TAX_ST_HR_DEVO_TXP                                          0          0
# TAX_ST_HR_DEVO_WRIT                                         0          0
# TAX_ST_IR_DEVO_TXP                                          0       1850
# TAX_ST_SR_DEVO_TXP                                          0        285
# TAXINC                                                  43500      24875
# TAXPAYER                                                    1          1
# TAXTERM                                                     0          0
# TEI                                                     38090      16170
# TI                                                      56090      37470
# TII                                                     18000      21300
# TOTTAX_DEVO_TXP                                          9800       3655
# UBISJA                                                      0          0
# WELSH_TXP                                                   0          0
# zzz_policyengine_adjusted_net_income                  56090.0    37470.0
# zzz_policyengine_dividend_allowance                    2000.0     2000.0
# zzz_policyengine_earned_taxable_income                25500.0    24875.0
# zzz_policyengine_gift_aid                                 0.0        0.0
# zzz_policyengine_income_tax                            9900.0     3555.0
# zzz_policyengine_other_tax_credits                        0.0     1420.0
# zzz_policyengine_pension_contributions                    0.0        0.0
# zzz_policyengine_pension_contributions_relief            90.0       95.0
# zzz_policyengine_personal_allowance                   12500.0    12500.0
# zzz_policyengine_private_pension_contributions_tax        0.0        0.0
# zzz_policyengine_property_allowance                       0.0        0.0
# zzz_policyengine_property_income                          0.0    21300.0
# zzz_policyengine_received_allowances                  12590.0    12595.0
# zzz_policyengine_savings_allowance                        0.0        0.0
# zzz_policyengine_taxable_pension_income                   0.0    13800.0
# zzz_policyengine_taxable_property_income                  0.0    21300.0
# zzz_policyengine_taxed_dividend_income                    0.0        0.0
# zzz_policyengine_taxed_income                         43500.0    24875.0
# zzz_policyengine_taxed_savings_income                 18000.0        0.0
#
#                                                       83159
# abs_error                                              100.0
# AGERANGE                                                   3
# BPADUE                                                     0
# CAPALL                                                     0
# COVNTS                                                     0
# DEFICIEN                                                   0
# DIVIDENDS                                                  0
# DSHIPS                                                     3
# EIDF                                                       0
# EMPINC                                                 37250
# EPB                                                      250
# error                                                 -100.0
# EXPS                                                       0
# FACT                                                 83.6044
# GIFTAID                                                    0
# GIFTINV                                                    0
# GORCODE                                                   11
# IIDF                                                       0
# INCBBS                                                     0
# INCPBEN                                                    0
# INCPROP                                                    0
# INDUSTRY07                                                 K
# LLIR_RESTRICT_AMT_TOT                                      0
# LOSSBF                                                     0
# MAIND                                                      0
# MAINSRCE                                                   1
# MAR                                                     STIR
# MCAS                                                       0
# MOTHDED                                                    0
# MOTHINC                                                    0
# OSSBEN                                                     0
# OTHERINC                                                   0
# OTHERINV                                                   0
# PAS                                                    12500
# PAY                                                    37000
# PENSION                                                    0
# PENSRLF                                                    0
# PROFITS                                                    0
# PSAV_XS                                                    0
# SCOT_TXP                                                   1
# SEINC_NUM                                                  0
# SEISS                                                      0
# SEX                                                        1
# SPA                                                        0
# SREF                                                15146778
# SRP                                                        0
# TAX_CRED                                                   0
# TAX_ST_AR_DEVO_TXP                                         0
# TAX_ST_AR_DEVO_WRIT                                        0
# TAX_ST_BR_DEVO_TXP                                      2115
# TAX_ST_BR_DEVO_WRIT                                        0
# TAX_ST_HR_DEVO_TXP                                         0
# TAX_ST_HR_DEVO_WRIT                                        0
# TAX_ST_IR_DEVO_TXP                                      2540
# TAX_ST_SR_DEVO_TXP                                       395
# TAXINC                                                 24750
# TAXPAYER                                                   1
# TAXTERM                                                    0
# TEI                                                    37250
# TI                                                     37250
# TII                                                        0
# TOTTAX_DEVO_TXP                                         5050
# UBISJA                                                     0
# WELSH_TXP                                                  0
# zzz_policyengine_adjusted_net_income                 37250.0
# zzz_policyengine_dividend_allowance                   2000.0
# zzz_policyengine_earned_taxable_income               24750.0
# zzz_policyengine_gift_aid                                0.0
# zzz_policyengine_income_tax                           4950.0
# zzz_policyengine_other_tax_credits                       0.0
# zzz_policyengine_pension_contributions                   0.0
# zzz_policyengine_pension_contributions_relief            0.0
# zzz_policyengine_personal_allowance                  12500.0
# zzz_policyengine_private_pension_contributions_tax       0.0
# zzz_policyengine_property_allowance                      0.0
# zzz_policyengine_property_income                         0.0
# zzz_policyengine_received_allowances                 12500.0
# zzz_policyengine_savings_allowance                       0.0
# zzz_policyengine_taxable_pension_income                  0.0
# zzz_policyengine_taxable_property_income                 0.0
# zzz_policyengine_taxed_dividend_income                   0.0
# zzz_policyengine_taxed_income                        24750.0
# zzz_policyengine_taxed_savings_income                    0.0

# %%
def error_category(error):
    if error <= 10:
        return "<=10"
    elif error < 100:
        return "<100"
    elif error < 1000:
        return "<1000"
    else:
        return ">=1000"
df.abs_error.apply(error_category).value_counts(normalize=True) * 100


#495286
# Out:
# abs_error
# <=10      83.793343
# <1000      8.434593
# <100       4.100823
# >=1000     3.671241
# Name: proportion, dtype: float64

# %%
result_df = df[(df['TI'] - df['zzz_policyengine_adjusted_net_income'] == 1000)].sort_values("abs_error", ascending=True).head().T.sort_index(key=lambda x: x.str.lower())

# Display the result
display(result_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [abs_error, AGERANGE, BPADUE, CAPALL, COVNTS, DEFICIEN, DIVIDENDS, DSHIPS, EIDF, EMPINC, EPB, error, EXPS, FACT, GIFTAID, GIFTINV, GORCODE, IIDF, INCBBS, INCPBEN, INCPROP, INDUSTRY07, LLIR_RESTRICT_AMT_TOT, LOSSBF, MAIND, MAINSRCE, MAR, MCAS, MOTHDED, MOTHINC, OSSBEN, OTHERINC, OTHERINV, PAS, PAY, PENSION, PENSRLF, PROFITS, PSAV_XS, SCOT_TXP, SEINC_NUM, SEISS, SEX, SPA, SREF, SRP, TAX_CRED, TAX_ST_AR_DEVO_TXP, TAX_ST_AR_DEVO_WRIT, TAX_ST_BR_DEVO_TXP, TAX_ST_BR_DEVO_WRIT, TAX_ST_HR_DEVO_TXP, TAX_ST_HR_DEVO_WRIT, TAX_ST_IR_DEVO_TXP, TAX_ST_SR_DEVO_TXP, TAXINC, TAXPAYER, TAXTERM, TEI, TI, TII, TOTTAX_DEVO_TXP, UBISJA, WELSH_TXP, zzz_policyengine_adjusted_net_income, zzz_policyengine_dividend_allowance, zzz_policyengine_earned_taxable_income, zzz_policyengine_gift_aid, zzz_policyengine_income_tax, zzz_policyengine_other_tax_credits, zzz_policyengine_pension_contributions, zzz_policyengine_pension_contributions_relief, zzz_policyengine_personal_allowance, zzz_policyengine_private_pension_contributions_tax, zzz_policyengine_property_allowance, zzz_policyengine_property_income, zzz_policyengine_received_allowances, zzz_policyengine_savings_allowance, zzz_policyengine_taxable_pension_income, zzz_policyengine_taxable_property_income, zzz_policyengine_taxed_dividend_income, zzz_policyengine_taxed_income, zzz_policyengine_taxed_savings_income]

# %%
result_df = df[(df['TAXINC'] > 100_000) & (df['TAXINC'] < 125_000)].sort_values("abs_error", ascending=True).head().T.sort_index(key=lambda x: x.str.lower())

# Display the result
display(result_df)
# Out:
#                                                       594775     676172  \
# abs_error                                                0.0        0.0
# AGERANGE                                                   3          5
# BPADUE                                                     0          0
# CAPALL                                                     0          0
# COVNTS                                                     0          0
# DEFICIEN                                                   0          0
# DIVIDENDS                                                  0        400
# DSHIPS                                                     3          1
# EIDF                                                       0          0
# EMPINC                                                117000      76800
# EPB                                                        0          0
# error                                                    0.0        0.0
# EXPS                                                       0          0
# FACT                                                10.74161  10.267938
# GIFTAID                                                    0          0
# GIFTINV                                                    0          0
# GORCODE                                                    6          8
# IIDF                                                       0          0
# INCBBS                                                     0          0
# INCPBEN                                                    0          0
# INCPROP                                                    0          0
# INDUSTRY07                                                 K       1600
# LLIR_RESTRICT_AMT_TOT                                      0          0
# LOSSBF                                                     0          0
# MAIND                                                      0          0
# MAINSRCE                                                   1          1
# MAR                                                     STHR       STHR
# MCAS                                                       0          0
# MOTHDED                                                    0          0
# MOTHINC                                                    0          0
# OSSBEN                                                     0          0
# OTHERINC                                                   0          0
# OTHERINV                                                   0          0
# PAS                                                     4000       3450
# PAY                                                   117000      76800
# PENSION                                                    0      40900
# PENSRLF                                                    0          0
# PROFITS                                                    0          0
# PSAV_XS                                                    0          0
# SCOT_TXP                                                   0          0
# SEINC_NUM                                                  0          0
# SEISS                                                      0          0
# SEX                                                        1          2
# SPA                                                        0          0
# SREF                                                15686026   15778630
# SRP                                                        0          0
# TAX_CRED                                                   0          0
# TAX_ST_AR_DEVO_TXP                                         0          0
# TAX_ST_AR_DEVO_WRIT                                        0          0
# TAX_ST_BR_DEVO_TXP                                      7500       7500
# TAX_ST_BR_DEVO_WRIT                                        0          0
# TAX_ST_HR_DEVO_TXP                                     30200      30700
# TAX_ST_HR_DEVO_WRIT                                        0          0
# TAX_ST_IR_DEVO_TXP                                         0          0
# TAX_ST_SR_DEVO_TXP                                         0          0
# TAXINC                                                113000     114650
# TAXPAYER                                                   1          1
# TAXTERM                                                    0          0
# TEI                                                   117000     117700
# TI                                                    117000     118100
# TII                                                        0        400
# TOTTAX_DEVO_TXP                                        37700      38200
# UBISJA                                                     0          0
# WELSH_TXP                                                  0          0
# zzz_policyengine_adjusted_net_income                117000.0   118100.0
# zzz_policyengine_dividend_allowance                   2000.0     2000.0
# zzz_policyengine_earned_taxable_income              113000.0   114250.0
# zzz_policyengine_gift_aid                                0.0        0.0
# zzz_policyengine_income_tax                          37700.0    38200.0
# zzz_policyengine_other_tax_credits                       0.0        0.0
# zzz_policyengine_pension_contributions                   0.0        0.0
# zzz_policyengine_pension_contributions_relief            0.0        0.0
# zzz_policyengine_personal_allowance                   4000.0     3450.0
# zzz_policyengine_private_pension_contributions_tax       0.0        0.0
# zzz_policyengine_property_allowance                      0.0        0.0
# zzz_policyengine_property_income                         0.0        0.0
# zzz_policyengine_received_allowances                  4000.0     3450.0
# zzz_policyengine_savings_allowance                       0.0        0.0
# zzz_policyengine_taxable_pension_income                  0.0    40900.0
# zzz_policyengine_taxable_property_income                 0.0        0.0
# zzz_policyengine_taxed_dividend_income                   0.0        0.0
# zzz_policyengine_taxed_income                       113000.0   114250.0
# zzz_policyengine_taxed_savings_income                    0.0        0.0
#
#                                                        447861     676180  \
# abs_error                                                 0.0        0.0
# AGERANGE                                                    5          3
# BPADUE                                                      0          0
# CAPALL                                                  13500          0
# COVNTS                                                      0          0
# DEFICIEN                                                    0          0
# DIVIDENDS                                                   0       2000
# DSHIPS                                                      3          3
# EIDF                                                        0          0
# EMPINC                                                      0          0
# EPB                                                         0          0
# error                                                     0.0        0.0
# EXPS                                                        0          0
# FACT                                                10.344375  10.192297
# GIFTAID                                                     0          0
# GIFTINV                                                     0          0
# GORCODE                                                     5          8
# IIDF                                                        0          0
# INCBBS                                                      0          0
# INCPBEN                                                     0          0
# INCPROP                                                     0       2750
# INDUSTRY07                                                  C          Q
# LLIR_RESTRICT_AMT_TOT                                       0       1780
# LOSSBF                                                      0          0
# MAIND                                                       0          0
# MAINSRCE                                                    4          1
# MAR                                                      STHR       STHR
# MCAS                                                        0          0
# MOTHDED                                                     0          0
# MOTHINC                                                     0          0
# OSSBEN                                                      0          0
# OTHERINC                                                    0          0
# OTHERINV                                                    0          0
# PAS                                                      1250       2625
# PAY                                                         0          0
# PENSION                                                     0          0
# PENSRLF                                                     0          0
# PROFITS                                                136000     115000
# PSAV_XS                                                     0          0
# SCOT_TXP                                                    0          0
# SEINC_NUM                                                   1          1
# SEISS                                                       0          0
# SEX                                                         1          1
# SPA                                                         0          0
# SREF                                                 15518791   15778639
# SRP                                                         0          0
# TAX_CRED                                                    0        355
# TAX_ST_AR_DEVO_TXP                                          0          0
# TAX_ST_AR_DEVO_WRIT                                         0          0
# TAX_ST_BR_DEVO_TXP                                       7500       7430
# TAX_ST_BR_DEVO_WRIT                                         0          0
# TAX_ST_HR_DEVO_TXP                                      33500      30765
# TAX_ST_HR_DEVO_WRIT                                         0          0
# TAX_ST_IR_DEVO_TXP                                          0          0
# TAX_ST_SR_DEVO_TXP                                          0          0
# TAXINC                                                 121250     117125
# TAXPAYER                                                    1          1
# TAXTERM                                                     0          0
# TEI                                                    122500     115000
# TI                                                     122500     119750
# TII                                                         0       4750
# TOTTAX_DEVO_TXP                                         41000      38195
# UBISJA                                                      0          0
# WELSH_TXP                                                   0          0
# zzz_policyengine_adjusted_net_income                 122500.0   119750.0
# zzz_policyengine_dividend_allowance                    2000.0     2000.0
# zzz_policyengine_earned_taxable_income               121250.0   115125.0
# zzz_policyengine_gift_aid                                 0.0        0.0
# zzz_policyengine_income_tax                           41000.0    38195.0
# zzz_policyengine_other_tax_credits                        0.0      355.0
# zzz_policyengine_pension_contributions                    0.0        0.0
# zzz_policyengine_pension_contributions_relief             0.0        0.0
# zzz_policyengine_personal_allowance                    1250.0     2625.0
# zzz_policyengine_private_pension_contributions_tax        0.0        0.0
# zzz_policyengine_property_allowance                       0.0        0.0
# zzz_policyengine_property_income                          0.0     2750.0
# zzz_policyengine_received_allowances                   1250.0     2625.0
# zzz_policyengine_savings_allowance                        0.0        0.0
# zzz_policyengine_taxable_pension_income                   0.0        0.0
# zzz_policyengine_taxable_property_income                  0.0     2750.0
# zzz_policyengine_taxed_dividend_income                    0.0        0.0
# zzz_policyengine_taxed_income                        121250.0   115125.0
# zzz_policyengine_taxed_savings_income                     0.0        0.0
#
#                                                       447882
# abs_error                                                0.0
# AGERANGE                                                   5
# BPADUE                                                     0
# CAPALL                                                     0
# COVNTS                                                     0
# DEFICIEN                                                   0
# DIVIDENDS                                                  0
# DSHIPS                                                     3
# EIDF                                                       0
# EMPINC                                                110000
# EPB                                                        0
# error                                                    0.0
# EXPS                                                       0
# FACT                                                10.74161
# GIFTAID                                                    0
# GIFTINV                                                    0
# GORCODE                                                    8
# IIDF                                                       0
# INCBBS                                                     0
# INCPBEN                                                    0
# INCPROP                                                    0
# INDUSTRY07                                                 G
# LLIR_RESTRICT_AMT_TOT                                      0
# LOSSBF                                                     0
# MAIND                                                      0
# MAINSRCE                                                   1
# MAR                                                     STHR
# MCAS                                                       0
# MOTHDED                                                    0
# MOTHINC                                                    0
# OSSBEN                                                     0
# OTHERINC                                                   0
# OTHERINV                                                   0
# PAS                                                     7500
# PAY                                                   110000
# PENSION                                                    0
# PENSRLF                                                    0
# PROFITS                                                    0
# PSAV_XS                                                    0
# SCOT_TXP                                                   0
# SEINC_NUM                                                  0
# SEISS                                                      0
# SEX                                                        1
# SPA                                                        0
# SREF                                                15518815
# SRP                                                        0
# TAX_CRED                                                   0
# TAX_ST_AR_DEVO_TXP                                         0
# TAX_ST_AR_DEVO_WRIT                                        0
# TAX_ST_BR_DEVO_TXP                                      7500
# TAX_ST_BR_DEVO_WRIT                                        0
# TAX_ST_HR_DEVO_TXP                                     26000
# TAX_ST_HR_DEVO_WRIT                                        0
# TAX_ST_IR_DEVO_TXP                                         0
# TAX_ST_SR_DEVO_TXP                                         0
# TAXINC                                                102500
# TAXPAYER                                                   1
# TAXTERM                                                    0
# TEI                                                   110000
# TI                                                    110000
# TII                                                        0
# TOTTAX_DEVO_TXP                                        33500
# UBISJA                                                     0
# WELSH_TXP                                                  0
# zzz_policyengine_adjusted_net_income                110000.0
# zzz_policyengine_dividend_allowance                   2000.0
# zzz_policyengine_earned_taxable_income              102500.0
# zzz_policyengine_gift_aid                                0.0
# zzz_policyengine_income_tax                          33500.0
# zzz_policyengine_other_tax_credits                       0.0
# zzz_policyengine_pension_contributions                   0.0
# zzz_policyengine_pension_contributions_relief            0.0
# zzz_policyengine_personal_allowance                   7500.0
# zzz_policyengine_private_pension_contributions_tax       0.0
# zzz_policyengine_property_allowance                      0.0
# zzz_policyengine_property_income                         0.0
# zzz_policyengine_received_allowances                  7500.0
# zzz_policyengine_savings_allowance                       0.0
# zzz_policyengine_taxable_pension_income                  0.0
# zzz_policyengine_taxable_property_income                 0.0
# zzz_policyengine_taxed_dividend_income                   0.0
# zzz_policyengine_taxed_income                       102500.0
# zzz_policyengine_taxed_savings_income                    0.0
